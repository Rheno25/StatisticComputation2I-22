# %%
import numpy as np
import matplotlib.pyplot as plt

data_raw = np.array([
    [2, 3, 7, 30],
    [9, 4, 6, 1],
    [8, 15, 2, 40],
    [20, 10, 2, 6]
])

plt.boxplot(data_raw)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24291c30b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24291c40100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24291c30820>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x24291c406a0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x24291c40970>,
# ...
#  'means': []}
